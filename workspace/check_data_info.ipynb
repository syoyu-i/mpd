# %%
import numpy as np
import pandas as pd

# %%
print(np.loadtxt(f'./../Multi-TPC/Data/Mocap/01-28-2022/Session_3_PC_1_mocap_data.txt', dtype='str').shape[0])
print(np.loadtxt(f'./../Multi-TPC/Data/Mocap/01-28-2022/Session_3_PC_1_mocap_data.txt', dtype='str').shape[1])
# Out:
# 21566
# 66

# %%
print(np.loadtxt(f'./../Multi-TPC/Data/Mocap/01-28-2022/Session_3_PC_2_mocap_data.txt', dtype='str').shape[0])
print(np.loadtxt(f'./../Multi-TPC/Data/Mocap/01-28-2022/Session_3_PC_2_mocap_data.txt', dtype='str').shape[1])
# Out:
# 21566
# 66

# %%
print(np.loadtxt(f'./../Multi-TPC/Data/Mocap/01-28-2022/Session_3_PC_3_mocap_data.txt', dtype='str').shape[0])
print(np.loadtxt(f'./../Multi-TPC/Data/Mocap/01-28-2022/Session_3_PC_3_mocap_data.txt', dtype='str').shape[1])
# Out:
# 21566
# 66
